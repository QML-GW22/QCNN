# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2664)

# %%
x = np.linspace(0, 100, 1000)
noise = np.random.normal(0,1,1000)
x_noise = x + noise
y = np.sin(x/(2*np.pi))
y_noise = np.sin(x_noise/(2*np.pi))
#noise = np.random.normal(0,1,10000)
# Out:
# 4388

# %%
yr=np.random.randn(1000)
plt.plot(x,yr)

# %%
plt.plot(x,y,alpha=0.5)
plt.plot(x,x_noise,alpha=0.5)
plt.plot(x,y_noise,alpha=0.5)
plt.show()

# %%
#10000

#5000 noise

#5000 signal + noise

# %%
##. Generate signal and nosie

x = np.linspace(0,100,1000)
for i in range(0,10000):
    
    j=np.random.uniform(0,1)
    noise = np.random.normal(0,j,1000)
    
    if i > 5000:
        #print('yes')
        output_noise=noise
    else:
        x_noise = x + noise
        y = np.sin(x/(2*np.pi))
        y_noise = np.sin(x_noise/(2*np.pi))
        output_noise=y_noise

# %%
plt.plot(x,output_noise,color='r')
plt.plot(x,jjj)
